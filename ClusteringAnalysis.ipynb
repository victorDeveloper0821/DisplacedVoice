# %% [markdown]
# ## Import Python Packages

# %%
#Importing packages
import pandas as pd
import requests
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from dotenv import dotenv_values

pd.set_option('display.max_columns', None) # show all columns
warnings.filterwarnings("ignore") # suppress warnings

# %% [markdown]
# ### 1.2 Save your API key as a variable:
# The getpass() function is used to prompt users to enter a password or other sensitive information (such as your API key) without showing the characters on the screen. We will save your API key as a variable so we can use it later in our code without needing to write it every time.

# %%
config = dotenv_values(".env")  
census_api_key = config['API_KEY']

##print(census_api_key)

# %% [markdown]
# Some links to explore what is available:
#
# *   Census ACS Data 5-Year Estimate: https://www.census.gov/programs-surveys/acs/data/data-via-api.html
# *   List item: Example URLs to use when querying Census data:
# https://api.census.gov/data/2023/acs/acs5/examples.html

# %%
#Saving Census input info as variables

census_code = 'B19013_001E' # 'Median Household Income', you can search a different available table as well
year = '2023' # The latest year the ACS has data for
state = '04' # State code for Arizona
county_code = '013' # The "*" here is a wildcard, meaning that it will query all of the available counties in the State

#Note: We will use the "*" for the county code for now, to get the info for all the counties in AZ,
# we will use the county code for Maricopa later on to filter the data.
# county_code = '013' #County code for Maricopa County

# %% [markdown]
# ### 1.2.1 Query the data from the Census API

# %% [markdown]
# As you can see in the output, our data is divided by **Census Tracks**. These "tracks" are the geographical divisions used by the Census to collect data.

# %%
### get census data
def fetchCensusData(census_code, year, state, county_code):
  census_url = f'https://api.census.gov/data/{year}/acs/acs5?get=NAME,{census_code}&for=tract:*&in=state:{state}&in=county:{county_code}&key={census_api_key}'
  response = requests.get(census_url)
  data = response.json()
  df_census = pd.DataFrame(data[1:], columns=data[0])
  return df_census

# %% [markdown]
# ### Total PopulationL Occupied v.s. rent

# %%
### Total Population in Occupied Housing Units by Tenure

codes_25008 = ['B25008_001E','B25008_002E','B25008_003E']

df_B25008 = fetchCensusData(",".join(codes_25008), year, state, county_code)

df_B25008[codes_25008] = df_B25008[codes_25008].astype(int)
df_B25008['OwnerOccupied'] = df_B25008['B25008_002E'] / df_B25008['B25008_001E']

df_B25008['RenterOccupied'] = df_B25008['B25008_003E'] / df_B25008['B25008_001E']

codes_25008.append('NAME')
df_B25008.drop(columns=codes_25008, inplace=True)

df_B25008['LiveType'] = df_B25008[['OwnerOccupied', 'RenterOccupied']].idxmax(axis=1)

df_B25008['GeoID'] = df_B25008['state'] + df_B25008['county'] + df_B25008['tract']
df_B25008.head()
# Out:
#   state county   tract  OwnerOccupied  RenterOccupied       LiveType  \
# 0    04    013  010102       0.921170        0.078830  OwnerOccupied
# 1    04    013  010103       0.969030        0.030970  OwnerOccupied
# 2    04    013  010104       0.968061        0.031939  OwnerOccupied
# 3    04    013  030401       0.930886        0.069114  OwnerOccupied
# 4    04    013  030402       0.904647        0.095353  OwnerOccupied
#
#          GeoID
# 0  04013010102
# 1  04013010103
# 2  04013010104
# 3  04013030401
# 4  04013030402

# %% [markdown]
# ### Gross Rent Percentage

# %%
### Gross Rent as a Percentage of Household Income in the Past 12 Months

codes_25070 = ['B25070_001E','B25070_002E','B25070_003E','B25070_004E','B25070_005E','B25070_006E','B25070_007E','B25070_008E','B25070_009E','B25070_010E']

df_B25070 = fetchCensusData(",".join(codes_25070),year,state,county_code)
df_B25070[codes_25070] = df_B25070[codes_25070].astype(int)
df_B25070 = df_B25070.loc[df_B25070['B25070_001E'] > 0,:]
df_B25070['lowBurdan'] = (df_B25070['B25070_002E'] + df_B25070['B25070_003E']) / df_B25070['B25070_001E']
df_B25070['moderateBurdan'] = (df_B25070['B25070_004E'] + df_B25070['B25070_005E']) / df_B25070['B25070_001E']
df_B25070['costBurdan']=  (df_B25070['B25070_007E']+ df_B25070['B25070_006E'] + df_B25070['B25070_008E'] + df_B25070['B25070_009E']) / df_B25070['B25070_001E']
df_B25070['highBurdan'] = df_B25070['B25070_010E'] / df_B25070['B25070_001E']

codes_25070.append('NAME')

df_B25070.drop(columns=codes_25070, inplace=True)
df_B25070['burden'] = df_B25070[['lowBurdan', 'moderateBurdan', 'costBurdan', 'highBurdan']].idxmax(axis=1)
df_B25070['GeoID'] = df_B25070['state'] + df_B25070['county'] + df_B25070['tract']

df_B25070.head()
# Out:
#   state county   tract  lowBurdan  moderateBurdan  costBurdan  highBurdan  \
# 0    04    013  010102   0.763441           0.000    0.000000    0.000000
# 1    04    013  010103   0.815385           0.000    0.000000    0.000000
# 2    04    013  010104   0.000000           0.000    0.196429    0.000000
# 3    04    013  030401   0.188119           0.000    0.217822    0.321782
# 4    04    013  030402   0.072000           0.472    0.336000    0.056000
#
#            burden        GeoID
# 0       lowBurdan  04013010102
# 1       lowBurdan  04013010103
# 2      costBurdan  04013010104
# 3      highBurdan  04013030401
# 4  moderateBurdan  04013030402

# %% [markdown]
# ### Race demographic data

# %%
### Race demographic data
# dictionary: https://api.census.gov/data/2023/acs/acs1/variables.html

codes_race = ['B02001_001E','B02001_002E','B02001_003E','B03001_003E','B02001_004E','B02001_005E','B02001_006E','B02001_007E','B02001_009E']
df_race = fetchCensusData(','.join(codes_race),year,state,county_code)

for n in codes_race:
  df_race[n] = df_race[n].astype(float)
  if n != 'B02001_001E':
    df_race[n] = df_race[n] / df_race['B02001_001E']

df_race.rename(columns={"B02001_001E": "Total", "B02001_002E": "White Alone", "B02001_003E": "Black Alone",'B03001_003E': "Hispanic or Latino",
                        "B02001_004E": "American Indian or Alaska Native Alone","B02001_005E": "Asian Alone",
                        "B02001_006E": "Native Hawaiian or Pacific Islander Alone","B02001_007E": "Some other race",
                        "B02001_009E": "Mixed race (exluding \"Some other race\")"},
                         inplace=True, errors = "raise")

races = ['White Alone','Black Alone','Hispanic or Latino','American Indian or Alaska Native Alone','Asian Alone',
                               'Native Hawaiian or Pacific Islander Alone','Some other race','Mixed race (exluding \"Some other race\")']
df_race['Majority'] = df_race[races].idxmax(axis=1)
df_race['GeoID'] = df_race['state'] + df_race['county'] + df_race['tract']
df_race.drop(columns=['NAME','Total'], inplace=True)

df_race.head()
# Out:
#    White Alone  Black Alone  Hispanic or Latino  \
# 0     0.916840     0.005427            0.085874
# 1     0.918229     0.003803            0.076881
# 2     0.955605     0.000000            0.010220
# 3     0.912521     0.005691            0.017707
# 4     0.927281     0.000000            0.014929
#
#    American Indian or Alaska Native Alone  Asian Alone  \
# 0                                0.000000     0.012291
# 1                                0.000000     0.000000
# 2                                0.000000     0.007027
# 3                                0.000000     0.025295
# 4                                0.004816     0.016855
#
#    Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0                                        0.0         0.002235
# 1                                        0.0         0.004890
# 2                                        0.0         0.000000
# 3                                        0.0         0.000000
# 4                                        0.0         0.008909
#
#    Mixed race (exluding "Some other race") state county   tract     Majority  \
# 0                                 0.020910    04    013  010102  White Alone
# 1                                 0.057865    04    013  010103  White Alone
# 2                                 0.025232    04    013  010104  White Alone
# 3                                 0.043634    04    013  030401  White Alone
# 4                                 0.006742    04    013  030402  White Alone
#
#          GeoID
# 0  04013010102
# 1  04013010103
# 2  04013010104
# 3  04013030401
# 4  04013030402

# %% [markdown]
# ### Tenure by Unit in Structure:

# %%
# categorize the house size
def categorize_data(df):
    categories = {
        "Single-family homes": ["B25032_003E", "B25032_004E"],
        "Small multi-unit buildings (2-4 units)": ["B25032_005E", "B25032_006E"],
        "Larger apartment complexes (5+ units)": ["B25032_007E", "B25032_008E", "B25032_009E", "B25032_010E"],
        "Mobile homes, boats, RVs, etc.": ["B25032_011E", "B25032_012E"],
    }

    result = {}
    for category, cols in categories.items():
        df[cols] = df[cols].astype(int)
        result[category] = df[cols].sum(axis=1)

    df_result = pd.DataFrame(result)

    # Totals
    df_result["total_units"] = df["B25032_001E"].astype(int)

    # calculate Ratios
    for category in categories.keys():
        df_result[category] = df_result[category] / df_result["total_units"]

    ## categorize the major houseType
    df_result['majorHouseType'] = df_result[['Single-family homes', 'Small multi-unit buildings (2-4 units)', 'Larger apartment complexes (5+ units)']].idxmax(axis=1)
    # contain tract, county, state
    df_result["tract"] = df["tract"]
    df_result["county"] = df["county"]
    df_result["state"] = df["state"]

    df_result = df_result.loc[df_result["total_units"] > 0,:]
    #
    df_result.drop(columns=["total_units"], inplace=True)

    return df_result

df_B25032 = fetchCensusData("B25032_001E,B25032_003E,B25032_004E,B25032_005E,B25032_006E,B25032_007E,B25032_008E,B25032_009E,B25032_010E,B25032_011E,B25032_012E", year, state, county_code)

df_B25032Sort = categorize_data(df_B25032)

df_B25032Sort['GeoID'] = df_B25032Sort['state'] + df_B25032Sort['county'] + df_B25032Sort['tract']

df_B25032Sort.head()
# Out:
#    Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0             0.967068                                0.000000
# 1             0.890501                                0.000000
# 2             0.967761                                0.000000
# 3             0.904664                                0.000000
# 4             0.837656                                0.029046
#
#    Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                               0.000000                        0.000000
# 1                               0.017150                        0.049472
# 2                               0.000000                        0.000000
# 3                               0.011969                        0.000000
# 4                               0.000000                        0.068465
#
#         majorHouseType   tract county state        GeoID
# 0  Single-family homes  010102    013    04  04013010102
# 1  Single-family homes  010103    013    04  04013010103
# 2  Single-family homes  010104    013    04  04013010104
# 3  Single-family homes  030401    013    04  04013030401
# 4  Single-family homes  030402    013    04  04013030402

# %% [markdown]
# ### Median income

# %%
median_df = fetchCensusData("B19013_001E", year=year, state=state, county_code=county_code)

median_df['B19013_001E'] = median_df['B19013_001E'].astype(int)

median_df.rename(columns={'B19013_001E': 'medianIncome'}, inplace=True)

median_df.drop(columns='NAME', inplace=True)
median_df['incomeLevel'] = pd.qcut(median_df['medianIncome'], q=4, labels=['Low', 'Moderate', 'High', 'Very High'])

median_df['GeoID'] = median_df['state'] + median_df['county'] + median_df['tract']

median_df_new = median_df.loc[median_df['medianIncome'] > 0, :]
median_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 988 entries, 0 to 1002
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   medianIncome  988 non-null    int64
#  1   state         988 non-null    object
#  2   county        988 non-null    object
#  3   tract         988 non-null    object
#  4   incomeLevel   988 non-null    category
#  5   GeoID         988 non-null    object
# dtypes: category(1), int64(1), object(4)
# memory usage: 47.5+ KB

# %% [markdown]
# **Median Income** has the values less than zero, we need to filter out these invalid numbers.

# %% [markdown]
# ### Get 2024 eviction data:

# %%
from io import BytesIO

url = 'https://raw.githubusercontent.com/UnitForDataScience/Projects-Spring-2025/refs/heads/main/Displaced%20Voices/Data/data_geocoded.csv'

response = requests.get(url, stream=True)
response.raise_for_status()  # 若連線失敗會報錯
csv_file = BytesIO(response.content)

eviction2024 = pd.read_csv(csv_file)

eviction2024.head()
# Out:
#          date  year    month                  street_address_1      city  \
# 0  2024-01-02  2024  2024-01           4404 W CHARTER OAK ROAD  GLENDALE
# 1  2024-01-02  2024  2024-01      7111 NORTH 75TH AVE APT 2043  GLENDALE
# 2  2024-01-02  2024  2024-01               3228 W Missouri Ave   Phoenix
# 3  2024-01-02  2024  2024-01               4045 WEST BELL ROAD   Phoenix
# 4  2024-01-02  2024  2024-01  1311 WEST BASELINE ROAD APT 2018     Tempe
#
#      state    county  zip_code             type street_address_1_clean  \
# 0  Arizona  Maricopa     85304  eviction_filing  4404 W CHARTER OAK RD
# 1  Arizona  Maricopa     85303  eviction_filing        7111 N 75TH AVE
# 2  Arizona  Maricopa     85017  eviction_filing    3228 W MISSOURI AVE
# 3  Arizona  Maricopa     85053  eviction_filing         4045 W BELL RD
# 4  Arizona  Maricopa     85283  eviction_filing     1311 W BASELINE RD
#
#    zip_code_clean                                 geocoded_address is_match  \
# 0           85304  4404 W CHARTER OAK RD, GLENDALE, Arizona, 85304    Match
# 1           85303        7111 N 75TH AVE, GLENDALE, Arizona, 85303    Match
# 2           85017     3228 W MISSOURI AVE, Phoenix, Arizona, 85017    Match
# 3           85053          4045 W BELL RD, Phoenix, Arizona, 85053    Match
# 4           85283        1311 W BASELINE RD, Tempe, Arizona, 85283    Match
#
#   is_exact                            returned_address  \
# 0    Exact  4404 W CHARTER OAK RD, GLENDALE, AZ, 85304
# 1    Exact        7111 N 75TH AVE, GLENDALE, AZ, 85303
# 2    Exact     3228 W MISSOURI AVE, PHOENIX, AZ, 85017
# 3    Exact          4045 W BELL RD, PHOENIX, AZ, 85053
# 4    Exact        1311 W BASELINE RD, TEMPE, AZ, 85283
#
#                          coordinates   tiger_line side  state_fips  \
# 0  -112.154995297645,33.597802814472  128177101.0    R         4.0
# 1  -112.220374489876,33.540036954393  128916826.0    R         4.0
# 2  -112.128648457377,33.516781172177  653211044.0    R         4.0
# 3  -112.145521353769,33.639356291529  128314536.0    L         4.0
# 4  -111.958388270239,33.378192590822  243919395.0    L         4.0
#
#    county_fips     tract   block        long        lat         geoid  \
# 0         13.0  104219.0  1021.0 -112.154995  33.597803  4.013104e+09
# 1         13.0   92705.0  1024.0 -112.220374  33.540037  4.013093e+09
# 2         13.0  107202.0  1022.0 -112.128648  33.516781  4.013107e+09
# 3         13.0  104226.0  1000.0 -112.145521  33.639356  4.013104e+09
# 4         13.0  320007.0  3002.0 -111.958388  33.378193  4.013320e+09
#
#          data_type
# 0  eviction_filing
# 1  eviction_filing
# 2  eviction_filing
# 3  eviction_filing
# 4  eviction_filing

# %%
# Remove rows with missing 'geoid' values
eviction2024.dropna(subset=['geoid'], inplace=True)

# Check for missing values again
missing_values = eviction2024.isnull().sum()
print(missing_values)

# Alternatively, get a summary of missing values
missing_values_summary = eviction2024.isnull().sum().sum()
print(f"Total missing values: {missing_values_summary}")

print(eviction2024.shape)
# Out:
# date                      0
# year                      0
# month                     0
# street_address_1          0
# city                      0
# state                     0
# county                    0
# zip_code                  0
# type                      0
# street_address_1_clean    0
# zip_code_clean            0
# geocoded_address          0
# is_match                  0
# is_exact                  0
# returned_address          0
# coordinates               0
# tiger_line                0
# side                      0
# state_fips                0
# county_fips               0
# tract                     0
# block                     0
# long                      0
# lat                       0
# geoid                     0
# data_type                 0
# dtype: int64
# Total missing values: 0
# (52900, 26)

# %%
eviction2024 = eviction2024.loc[:,['geoid', 'zip_code', 'type']]

eviction2024['zip_code'] = eviction2024['zip_code'].astype(str)

eviction2024['GeoID'] = eviction2024['geoid'].astype(int).astype(str).str.zfill(11)
eviction2024.head()
# Out:
#           geoid zip_code             type        GeoID
# 0  4.013104e+09    85304  eviction_filing  04013104219
# 1  4.013093e+09    85303  eviction_filing  04013092705
# 2  4.013107e+09    85017  eviction_filing  04013107202
# 3  4.013104e+09    85053  eviction_filing  04013104226
# 4  4.013320e+09    85283  eviction_filing  04013320007

# %%
eviction_count = eviction2024.groupby(['GeoID', 'zip_code'])['type'].count().reset_index()

eviction_count.rename(columns={'type': 'filedEviction'}, inplace=True)

eviction_count.head(40)
# Out:
#           GeoID zip_code  filedEviction
# 0   04013010102    85331              1
# 1   04013010103    85262              1
# 2   04013030401    85331              1
# 3   04013030401    85377              1
# 4   04013030402    85331             12
# 5   04013040502    85390             29
# 6   04013040506    85375              2
# 7   04013040507    85375              3
# 8   04013040514    85375              3
# 9   04013040515    85320              1
# 10  04013040515    85390              7
# 11  04013040516    85361              1
# 12  04013040516    85396              2
# 13  04013040522    85375              2
# 14  04013040523    85375              1
# 15  04013040526    85374              1
# 16  04013040527    85374              9
# 17  04013040530    85374             13
# 18  04013040531    85374             22
# 19  04013040532    85373             11
# 20  04013040532    85375              2
# 21  04013040533    85383              1
# 22  04013040535    85383              6
# 23  04013040535    85387              1
# 24  04013040536    85383             20
# 25  04013040538    85378              1
# 26  04013040538    85387             12
# 27  04013040539    85361              1
# 28  04013040539    85387             12
# 29  04013040539    85390              4
# 30  04013040539    85396              1
# 31  04013040540    85361              2
# 32  04013040540    85374             13
# 33  04013040540    85387              9
# 34  04013040541    85361              6
# 35  04013050603    85037              1
# 36  04013050603    85354              3
# 37  04013050604    85354              3
# 38  04013050609    85016              1
# 39  04013050609    85326             28

# %%
column_sum = eviction_count['filedEviction'].sum()
print(column_sum)
# Out:
# 52900

# %% [markdown]
# ## Merging the Tables
#
# In our case, the dataframes share common variables such as **state**, **county**, **tract**, and GeoID.
#
# GeoID is a concatenation of **state**, **county**, and **tract**, forming an 11-digit identifier.
#
# **P.S. A tract is a precise geographic identifier that is updated every five years.**

# %%
df_economic = median_df_new.merge(df_B25032Sort.drop(columns=['state', 'county', 'tract']), how='inner', on='GeoID').\
merge(df_B25070.drop(columns=['state', 'county', 'tract']), how='inner', on='GeoID').\
merge(df_B25008.drop(columns=['state', 'county', 'tract']), how='inner', on='GeoID').\
merge(df_race.drop(columns=['state', 'county', 'tract']),how='inner', on='GeoID')

df_economic.head()
# Out:
#    medianIncome state county   tract incomeLevel        GeoID  \
# 0        188486    04    013  010102   Very High  04013010102
# 1        117813    04    013  010103   Very High  04013010103
# 2        140587    04    013  010104   Very High  04013010104
# 3        145865    04    013  030401   Very High  04013030401
# 4        108031    04    013  030402        High  04013030402
#
#    Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0             0.967068                                0.000000
# 1             0.890501                                0.000000
# 2             0.967761                                0.000000
# 3             0.904664                                0.000000
# 4             0.837656                                0.029046
#
#    Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                               0.000000                        0.000000
# 1                               0.017150                        0.049472
# 2                               0.000000                        0.000000
# 3                               0.011969                        0.000000
# 4                               0.000000                        0.068465
#
#         majorHouseType  lowBurdan  moderateBurdan  costBurdan  highBurdan  \
# 0  Single-family homes   0.763441           0.000    0.000000    0.000000
# 1  Single-family homes   0.815385           0.000    0.000000    0.000000
# 2  Single-family homes   0.000000           0.000    0.196429    0.000000
# 3  Single-family homes   0.188119           0.000    0.217822    0.321782
# 4  Single-family homes   0.072000           0.472    0.336000    0.056000
#
#            burden  OwnerOccupied  RenterOccupied       LiveType  White Alone  \
# 0       lowBurdan       0.921170        0.078830  OwnerOccupied     0.916840
# 1       lowBurdan       0.969030        0.030970  OwnerOccupied     0.918229
# 2      costBurdan       0.968061        0.031939  OwnerOccupied     0.955605
# 3      highBurdan       0.930886        0.069114  OwnerOccupied     0.912521
# 4  moderateBurdan       0.904647        0.095353  OwnerOccupied     0.927281
#
#    Black Alone  Hispanic or Latino  American Indian or Alaska Native Alone  \
# 0     0.005427            0.085874                                0.000000
# 1     0.003803            0.076881                                0.000000
# 2     0.000000            0.010220                                0.000000
# 3     0.005691            0.017707                                0.000000
# 4     0.000000            0.014929                                0.004816
#
#    Asian Alone  Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0     0.012291                                        0.0         0.002235
# 1     0.000000                                        0.0         0.004890
# 2     0.007027                                        0.0         0.000000
# 3     0.025295                                        0.0         0.000000
# 4     0.016855                                        0.0         0.008909
#
#    Mixed race (exluding "Some other race")     Majority
# 0                                 0.020910  White Alone
# 1                                 0.057865  White Alone
# 2                                 0.025232  White Alone
# 3                                 0.043634  White Alone
# 4                                 0.006742  White Alone

# %% [markdown]
# ## Merge demographic data with eviction record in 2024

# %%
fullDataset = eviction_count.merge(df_economic, how='right', on='GeoID')
fullDataset
# Out:
#             GeoID zip_code  filedEviction  medianIncome state county   tract  \
# 0     04013010102    85331            1.0        188486    04    013  010102
# 1     04013010103    85262            1.0        117813    04    013  010103
# 2     04013010104      NaN            NaN        140587    04    013  010104
# 3     04013030401    85331            1.0        145865    04    013  030401
# 4     04013030401    85377            1.0        145865    04    013  030401
# ...           ...      ...            ...           ...   ...    ...     ...
# 1528  04013817500      NaN            NaN         64926    04    013  817500
# 1529  04013817600    85212            1.0        138208    04    013  817600
# 1530  04013941000      NaN            NaN         49926    04    013  941000
# 1531  04013941200      NaN            NaN         58229    04    013  941200
# 1532  04013941300    85257           19.0         42500    04    013  941300
#
#      incomeLevel  Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0      Very High             0.967068                                0.000000
# 1      Very High             0.890501                                0.000000
# 2      Very High             0.967761                                0.000000
# 3      Very High             0.904664                                0.000000
# 4      Very High             0.904664                                0.000000
# ...          ...                  ...                                     ...
# 1528    Moderate             0.801780                                0.000000
# 1529   Very High             0.861401                                0.006194
# 1530         Low             0.654676                                0.000000
# 1531         Low             0.797048                                0.000000
# 1532         Low             0.415005                                0.000000
#
#       Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                                  0.000000                        0.000000
# 1                                  0.017150                        0.049472
# 2                                  0.000000                        0.000000
# 3                                  0.011969                        0.000000
# 4                                  0.011969                        0.000000
# ...                                     ...                             ...
# 1528                               0.000000                        0.013650
# 1529                               0.000000                        0.031746
# 1530                               0.000000                        0.038849
# 1531                               0.000000                        0.095941
# 1532                               0.000000                        0.451207
#
#            majorHouseType  lowBurdan  moderateBurdan  costBurdan  highBurdan  \
# 0     Single-family homes   0.763441        0.000000    0.000000    0.000000
# 1     Single-family homes   0.815385        0.000000    0.000000    0.000000
# 2     Single-family homes   0.000000        0.000000    0.196429    0.000000
# 3     Single-family homes   0.188119        0.000000    0.217822    0.321782
# 4     Single-family homes   0.188119        0.000000    0.217822    0.321782
# ...                   ...        ...             ...         ...         ...
# 1528  Single-family homes   0.028939        0.173633    0.254019    0.456592
# 1529  Single-family homes   0.153846        0.292308    0.123077    0.273077
# 1530  Single-family homes   0.164319        0.093897    0.107981    0.070423
# 1531  Single-family homes   0.172414        0.137931    0.137931    0.137931
# 1532  Single-family homes   0.203922        0.450980    0.121569    0.152941
#
#               burden  OwnerOccupied  RenterOccupied       LiveType  \
# 0          lowBurdan       0.921170        0.078830  OwnerOccupied
# 1          lowBurdan       0.969030        0.030970  OwnerOccupied
# 2         costBurdan       0.968061        0.031939  OwnerOccupied
# 3         highBurdan       0.930886        0.069114  OwnerOccupied
# 4         highBurdan       0.930886        0.069114  OwnerOccupied
# ...              ...            ...             ...            ...
# 1528      highBurdan       0.859898        0.140102  OwnerOccupied
# 1529  moderateBurdan       0.914421        0.085579  OwnerOccupied
# 1530       lowBurdan       0.650252        0.349748  OwnerOccupied
# 1531       lowBurdan       0.926966        0.073034  OwnerOccupied
# 1532  moderateBurdan       0.876469        0.123531  OwnerOccupied
#
#       White Alone  Black Alone  Hispanic or Latino  \
# 0        0.916840     0.005427            0.085874
# 1        0.918229     0.003803            0.076881
# 2        0.955605     0.000000            0.010220
# 3        0.912521     0.005691            0.017707
# 4        0.912521     0.005691            0.017707
# ...           ...          ...                 ...
# 1528     0.936681     0.005095            0.052038
# 1529     0.716588     0.026947            0.150169
# 1530     0.030410     0.003543            0.118984
# 1531     0.113296     0.002809            0.248127
# 1532     0.223802     0.003827            0.164389
#
#       American Indian or Alaska Native Alone  Asian Alone  \
# 0                                   0.000000     0.012291
# 1                                   0.000000     0.000000
# 2                                   0.000000     0.007027
# 3                                   0.000000     0.025295
# 4                                   0.000000     0.025295
# ...                                      ...          ...
# 1528                                0.003639     0.006186
# 1529                                0.024103     0.048883
# 1530                                0.807204     0.023324
# 1531                                0.738764     0.016854
# 1532                                0.659377     0.000000
#
#       Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0                                           0.0         0.002235
# 1                                           0.0         0.004890
# 2                                           0.0         0.000000
# 3                                           0.0         0.000000
# 4                                           0.0         0.000000
# ...                                         ...              ...
# 1528                                        0.0         0.002183
# 1529                                        0.0         0.058226
# 1530                                        0.0         0.027753
# 1531                                        0.0         0.026217
# 1532                                        0.0         0.013122
#
#       Mixed race (exluding "Some other race")  \
# 0                                    0.020910
# 1                                    0.057865
# 2                                    0.025232
# 3                                    0.043634
# 4                                    0.043634
# ...                                       ...
# 1528                                 0.021470
# 1529                                 0.056601
# 1530                                 0.040449
# 1531                                 0.014045
# 1532                                 0.025879
#
#                                     Majority
# 0                                White Alone
# 1                                White Alone
# 2                                White Alone
# 3                                White Alone
# 4                                White Alone
# ...                                      ...
# 1528                             White Alone
# 1529                             White Alone
# 1530  American Indian or Alaska Native Alone
# 1531  American Indian or Alaska Native Alone
# 1532  American Indian or Alaska Native Alone
#
# [1533 rows x 30 columns]

# %%
fullDataset.shape
# Out:
# (1533, 30)

# %%
column_sum = fullDataset['filedEviction'].sum()
print(column_sum)
# Out:
# 52877.0

# %%
fullDataset.isnull().sum()
# Out:
# GeoID                                         0
# zip_code                                     54
# filedEviction                                54
# medianIncome                                  0
# state                                         0
# county                                        0
# tract                                         0
# incomeLevel                                   0
# Single-family homes                           0
# Small multi-unit buildings (2-4 units)        0
# Larger apartment complexes (5+ units)         0
# Mobile homes, boats, RVs, etc.                0
# majorHouseType                                0
# lowBurdan                                     0
# moderateBurdan                                0
# costBurdan                                    0
# highBurdan                                    0
# burden                                        0
# OwnerOccupied                                 0
# RenterOccupied                                0
# LiveType                                      0
# White Alone                                   0
# Black Alone                                   0
# Hispanic or Latino                            0
# American Indian or Alaska Native Alone        0
# Asian Alone                                   0
# Native Hawaiian or Pacific Islander Alone     0
# Some other race                               0
# Mixed race (exluding "Some other race")       0
# Majority                                      0
# dtype: int64

# %%
fullDataset['filedEviction'] = fullDataset['filedEviction'].fillna(0).astype(int)

fullDataset['zip_code'] = fullDataset['zip_code'].fillna('N/A')

fullDataset.isnull().sum()
# Out:
# GeoID                                        0
# zip_code                                     0
# filedEviction                                0
# medianIncome                                 0
# state                                        0
# county                                       0
# tract                                        0
# incomeLevel                                  0
# Single-family homes                          0
# Small multi-unit buildings (2-4 units)       0
# Larger apartment complexes (5+ units)        0
# Mobile homes, boats, RVs, etc.               0
# majorHouseType                               0
# lowBurdan                                    0
# moderateBurdan                               0
# costBurdan                                   0
# highBurdan                                   0
# burden                                       0
# OwnerOccupied                                0
# RenterOccupied                               0
# LiveType                                     0
# White Alone                                  0
# Black Alone                                  0
# Hispanic or Latino                           0
# American Indian or Alaska Native Alone       0
# Asian Alone                                  0
# Native Hawaiian or Pacific Islander Alone    0
# Some other race                              0
# Mixed race (exluding "Some other race")      0
# Majority                                     0
# dtype: int64

# %%
fullDataset.isnull().sum()
# Out:
# GeoID                                        0
# zip_code                                     0
# filedEviction                                0
# medianIncome                                 0
# state                                        0
# county                                       0
# tract                                        0
# incomeLevel                                  0
# Single-family homes                          0
# Small multi-unit buildings (2-4 units)       0
# Larger apartment complexes (5+ units)        0
# Mobile homes, boats, RVs, etc.               0
# majorHouseType                               0
# lowBurdan                                    0
# moderateBurdan                               0
# costBurdan                                   0
# highBurdan                                   0
# burden                                       0
# OwnerOccupied                                0
# RenterOccupied                               0
# LiveType                                     0
# White Alone                                  0
# Black Alone                                  0
# Hispanic or Latino                           0
# American Indian or Alaska Native Alone       0
# Asian Alone                                  0
# Native Hawaiian or Pacific Islander Alone    0
# Some other race                              0
# Mixed race (exluding "Some other race")      0
# Majority                                     0
# dtype: int64

# %% [markdown]
# ## Section 2: Clustering Analysis
#
# In this analysis, we plan to use the k-means algorithm to identify distinct groups of tracts through clustering.
#
# After performing the clustering analysis, we will conduct statistical tests such as a one-way ANOVA or trend tests to examine how factors like median income, burden of gross income, and the ratio of renters to owners vary across the clusters. Additionally, we will analyze the overall distribution of these variables.

# %% [markdown]
# ### About K-means algorithms:
#
# For the first thing, we need to find out the best parameter, how many clusters we will have in the datasets.
#
# We will use the `scikit-learn` to find the best groups we will use.

# %%
fullDataCopy = fullDataset.copy()

df_Kmeans = fullDataCopy.drop(columns=['GeoID','state', 'county', 'tract','zip_code','LiveType', 'burden','majorHouseType','incomeLevel','Majority', 'filedEviction'])

df_Kmeans.head()
# Out:
#    medianIncome  Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0        188486             0.967068                                     0.0
# 1        117813             0.890501                                     0.0
# 2        140587             0.967761                                     0.0
# 3        145865             0.904664                                     0.0
# 4        145865             0.904664                                     0.0
#
#    Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                               0.000000                        0.000000
# 1                               0.017150                        0.049472
# 2                               0.000000                        0.000000
# 3                               0.011969                        0.000000
# 4                               0.011969                        0.000000
#
#    lowBurdan  moderateBurdan  costBurdan  highBurdan  OwnerOccupied  \
# 0   0.763441             0.0    0.000000    0.000000       0.921170
# 1   0.815385             0.0    0.000000    0.000000       0.969030
# 2   0.000000             0.0    0.196429    0.000000       0.968061
# 3   0.188119             0.0    0.217822    0.321782       0.930886
# 4   0.188119             0.0    0.217822    0.321782       0.930886
#
#    RenterOccupied  White Alone  Black Alone  Hispanic or Latino  \
# 0        0.078830     0.916840     0.005427            0.085874
# 1        0.030970     0.918229     0.003803            0.076881
# 2        0.031939     0.955605     0.000000            0.010220
# 3        0.069114     0.912521     0.005691            0.017707
# 4        0.069114     0.912521     0.005691            0.017707
#
#    American Indian or Alaska Native Alone  Asian Alone  \
# 0                                     0.0     0.012291
# 1                                     0.0     0.000000
# 2                                     0.0     0.007027
# 3                                     0.0     0.025295
# 4                                     0.0     0.025295
#
#    Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0                                        0.0         0.002235
# 1                                        0.0         0.004890
# 2                                        0.0         0.000000
# 3                                        0.0         0.000000
# 4                                        0.0         0.000000
#
#    Mixed race (exluding "Some other race")
# 0                                 0.020910
# 1                                 0.057865
# 2                                 0.025232
# 3                                 0.043634
# 4                                 0.043634

# %%
scaler = StandardScaler()

df_Kmeans['medianIncome'] = scaler.fit_transform(df_Kmeans[['medianIncome']])

df_Kmeans.head()
# Out:
#    medianIncome  Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0      2.881157             0.967068                                     0.0
# 1      0.889811             0.890501                                     0.0
# 2      1.531512             0.967761                                     0.0
# 3      1.680229             0.904664                                     0.0
# 4      1.680229             0.904664                                     0.0
#
#    Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                               0.000000                        0.000000
# 1                               0.017150                        0.049472
# 2                               0.000000                        0.000000
# 3                               0.011969                        0.000000
# 4                               0.011969                        0.000000
#
#    lowBurdan  moderateBurdan  costBurdan  highBurdan  OwnerOccupied  \
# 0   0.763441             0.0    0.000000    0.000000       0.921170
# 1   0.815385             0.0    0.000000    0.000000       0.969030
# 2   0.000000             0.0    0.196429    0.000000       0.968061
# 3   0.188119             0.0    0.217822    0.321782       0.930886
# 4   0.188119             0.0    0.217822    0.321782       0.930886
#
#    RenterOccupied  White Alone  Black Alone  Hispanic or Latino  \
# 0        0.078830     0.916840     0.005427            0.085874
# 1        0.030970     0.918229     0.003803            0.076881
# 2        0.031939     0.955605     0.000000            0.010220
# 3        0.069114     0.912521     0.005691            0.017707
# 4        0.069114     0.912521     0.005691            0.017707
#
#    American Indian or Alaska Native Alone  Asian Alone  \
# 0                                     0.0     0.012291
# 1                                     0.0     0.000000
# 2                                     0.0     0.007027
# 3                                     0.0     0.025295
# 4                                     0.0     0.025295
#
#    Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0                                        0.0         0.002235
# 1                                        0.0         0.004890
# 2                                        0.0         0.000000
# 3                                        0.0         0.000000
# 4                                        0.0         0.000000
#
#    Mixed race (exluding "Some other race")
# 0                                 0.020910
# 1                                 0.057865
# 2                                 0.025232
# 3                                 0.043634
# 4                                 0.043634

# %%
wcss = []
k_range = range(2, 18)
for k in k_range:
  kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
  kmeans.fit(df_Kmeans)
  wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(k_range, wcss, marker='o', linestyle='-', color='b')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-cluster sum of squares)')
plt.show()

# %%
from sklearn.metrics import silhouette_score

for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(df_Kmeans)
    score = silhouette_score(df_Kmeans, kmeans.labels_)
    print(f"Silhouette score for k={k}: {score}")
# Out:
# Silhouette score for k=2: 0.4453382561625397
# Silhouette score for k=3: 0.35294296649810386
# Silhouette score for k=4: 0.2747868553199738
# Silhouette score for k=5: 0.25907278831439196
# Silhouette score for k=6: 0.24320669868494035
# Silhouette score for k=7: 0.23661650498941908
# Silhouette score for k=8: 0.2118098651412616
# Silhouette score for k=9: 0.21097692214826044

# %%
#Calinski-Harabasz Index
from sklearn.metrics import calinski_harabasz_score

for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(df_Kmeans)
    score = calinski_harabasz_score(df_Kmeans, kmeans.labels_)
    print(f"CH Index for k={k}: {score}")
# Out:
# CH Index for k=2: 1683.9396937622196
# CH Index for k=3: 1577.4391443473246
# CH Index for k=4: 1369.0808963624734
# CH Index for k=5: 1221.3815215054474
# CH Index for k=6: 1086.4438122664083
# CH Index for k=7: 1016.5574446419586
# CH Index for k=8: 922.3213621038695
# CH Index for k=9: 880.7899682521527

# %%
#Davies-Bouldin Index
from sklearn.metrics import davies_bouldin_score

for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=42).fit(df_Kmeans)
    score = davies_bouldin_score(df_Kmeans, kmeans.labels_)
    print(f"DB Index for k={k}: {score}")
# Out:
# DB Index for k=2: 0.8293612334631235
# DB Index for k=3: 0.9413375943092902
# DB Index for k=4: 1.1523683992863853
# DB Index for k=5: 1.144046167809736
# DB Index for k=6: 1.2815155679141998
# DB Index for k=7: 1.2768186265661068
# DB Index for k=8: 1.371219406790452
# DB Index for k=9: 1.3268611364099223

# %%
optimizedK = 9
kmeansPred = KMeans(n_clusters=optimizedK, random_state=42, n_init=10)
kmeansPred.fit(df_Kmeans)
fullDataset['cluster'] = kmeansPred.labels_+1

fullDataset.head()
# Out:
#          GeoID zip_code  filedEviction  medianIncome state county   tract  \
# 0  04013010102    85331              1        188486    04    013  010102
# 1  04013010103    85262              1        117813    04    013  010103
# 2  04013010104      N/A              0        140587    04    013  010104
# 3  04013030401    85331              1        145865    04    013  030401
# 4  04013030401    85377              1        145865    04    013  030401
#
#   incomeLevel  Single-family homes  Small multi-unit buildings (2-4 units)  \
# 0   Very High             0.967068                                     0.0
# 1   Very High             0.890501                                     0.0
# 2   Very High             0.967761                                     0.0
# 3   Very High             0.904664                                     0.0
# 4   Very High             0.904664                                     0.0
#
#    Larger apartment complexes (5+ units)  Mobile homes, boats, RVs, etc.  \
# 0                               0.000000                        0.000000
# 1                               0.017150                        0.049472
# 2                               0.000000                        0.000000
# 3                               0.011969                        0.000000
# 4                               0.011969                        0.000000
#
#         majorHouseType  lowBurdan  moderateBurdan  costBurdan  highBurdan  \
# 0  Single-family homes   0.763441             0.0    0.000000    0.000000
# 1  Single-family homes   0.815385             0.0    0.000000    0.000000
# 2  Single-family homes   0.000000             0.0    0.196429    0.000000
# 3  Single-family homes   0.188119             0.0    0.217822    0.321782
# 4  Single-family homes   0.188119             0.0    0.217822    0.321782
#
#        burden  OwnerOccupied  RenterOccupied       LiveType  White Alone  \
# 0   lowBurdan       0.921170        0.078830  OwnerOccupied     0.916840
# 1   lowBurdan       0.969030        0.030970  OwnerOccupied     0.918229
# 2  costBurdan       0.968061        0.031939  OwnerOccupied     0.955605
# 3  highBurdan       0.930886        0.069114  OwnerOccupied     0.912521
# 4  highBurdan       0.930886        0.069114  OwnerOccupied     0.912521
#
#    Black Alone  Hispanic or Latino  American Indian or Alaska Native Alone  \
# 0     0.005427            0.085874                                     0.0
# 1     0.003803            0.076881                                     0.0
# 2     0.000000            0.010220                                     0.0
# 3     0.005691            0.017707                                     0.0
# 4     0.005691            0.017707                                     0.0
#
#    Asian Alone  Native Hawaiian or Pacific Islander Alone  Some other race  \
# 0     0.012291                                        0.0         0.002235
# 1     0.000000                                        0.0         0.004890
# 2     0.007027                                        0.0         0.000000
# 3     0.025295                                        0.0         0.000000
# 4     0.025295                                        0.0         0.000000
#
#    Mixed race (exluding "Some other race")     Majority  cluster
# 0                                 0.020910  White Alone        4
# 1                                 0.057865  White Alone        1
# 2                                 0.025232  White Alone        7
# 3                                 0.043634  White Alone        7
# 4                                 0.043634  White Alone        7

# %%
fullDataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1533 entries, 0 to 1532
# Data columns (total 31 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GeoID                                      1533 non-null   object
#  1   zip_code                                   1533 non-null   object
#  2   filedEviction                              1533 non-null   int64
#  3   medianIncome                               1533 non-null   int64
#  4   state                                      1533 non-null   object
#  5   county                                     1533 non-null   object
#  6   tract                                      1533 non-null   object
#  7   incomeLevel                                1533 non-null   category
#  8   Single-family homes                        1533 non-null   float64
#  9   Small multi-unit buildings (2-4 units)     1533 non-null   float64
#  10  Larger apartment complexes (5+ units)      1533 non-null   float64
#  11  Mobile homes, boats, RVs, etc.             1533 non-null   float64
#  12  majorHouseType                             1533 non-null   object
#  13  lowBurdan                                  1533 non-null   float64
#  14  moderateBurdan                             1533 non-null   float64
#  15  costBurdan                                 1533 non-null   float64
#  16  highBurdan                                 1533 non-null   float64
#  17  burden                                     1533 non-null   object
#  18  OwnerOccupied                              1533 non-null   float64
#  19  RenterOccupied                             1533 non-null   float64
#  20  LiveType                                   1533 non-null   object
#  21  White Alone                                1533 non-null   float64
#  22  Black Alone                                1533 non-null   float64
#  23  Hispanic or Latino                         1533 non-null   float64
#  24  American Indian or Alaska Native Alone     1533 non-null   float64
#  25  Asian Alone                                1533 non-null   float64
#  26  Native Hawaiian or Pacific Islander Alone  1533 non-null   float64
#  27  Some other race                            1533 non-null   float64
#  28  Mixed race (exluding "Some other race")    1533 non-null   float64
#  29  Majority                                   1533 non-null   object
#  30  cluster                                    1533 non-null   int32
# dtypes: category(1), float64(18), int32(1), int64(2), object(9)
# memory usage: 355.1+ KB

# %%
# 設定 Seaborn 主題風格
sns.set_theme(style="whitegrid", font_scale=1.1)

plt.figure(figsize=(10, 6))

# 畫 boxplot
sns.boxplot(
    x='cluster',
    y='medianIncome',
    data=fullDataset,
    palette="pastel",
    width=0.6,
    linewidth=1.5
)

# 可選：加上 swarmplot 看 raw point 分布（樣本數不大時推薦）
# sns.swarmplot(x='cluster', y='medianIncome', data=fullDataset, color=".25", alpha=0.6)

# 標題與標籤美化
plt.title("Median Income Distribution by Cluster", fontsize=16, fontweight='bold')
plt.xlabel("Cluster", fontsize=13)
plt.ylabel("Median Income", fontsize=13)

# 加上格線
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# 設定 Seaborn 主題風格
sns.set_theme(style="whitegrid", font_scale=1.1)

plt.figure(figsize=(10, 6))

# 畫 boxplot
sns.boxplot(
    x='cluster',
    y='filedEviction',
    data=fullDataset,
    palette="pastel",
    width=0.6,
    linewidth=1.5
)

# 可選：加上 swarmplot 看 raw point 分布（樣本數不大時推薦）
# sns.swarmplot(x='cluster', y='medianIncome', data=fullDataset, color=".25", alpha=0.6)

# 標題與標籤美化
plt.title("Filed Eviction cases Distribution by Cluster", fontsize=16, fontweight='bold')
plt.xlabel("Cluster", fontsize=13)
plt.ylabel("Median Income", fontsize=13)

# 加上格線
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
# 建立簡化命名的 mapping
race_col_mapping = {
    "White Alone": "White",
    "Black Alone": "Black",
    "Hispanic or Latino": "Hispanic",
    "Asian Alone": "Asian",
    "American Indian or Alaska Native Alone": "Native American",
    "Native Hawaiian or Pacific Islander Alone": "Pacific Islander",
    "Some other race": "Other",
    "Mixed race (exluding \"Some other race\")": "Mixed"
}

# 篩選與改名種族欄位
race_cols_original = list(race_col_mapping.keys())
df_race = fullDataset[["cluster"] + race_cols_original].copy()
df_race.rename(columns=race_col_mapping, inplace=True)

# 群組平均 & 正規化為比例
race_avg = df_race.groupby("cluster").mean()
race_prop = race_avg.div(race_avg.sum(axis=1), axis=0)

# 畫堆疊長條圖
race_prop.T.plot(kind='bar', stacked=True, figsize=(12, 6), colormap="tab20")
plt.ylabel("Proportion")
plt.title("Racial Composition by Cluster")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# 定義負擔欄位
burden_cols = ["lowBurdan", "moderateBurdan", "costBurdan", "highBurdan"]

# 計算每個 cluster 中各 burden 類型的平均值
burden_avg = fullDataset.groupby("cluster")[burden_cols].mean()

# 計算百分比（橫向正規化）
burden_percent = burden_avg.div(burden_avg.sum(axis=1), axis=0).reset_index()

# 將資料轉為長格式供 seaborn 使用
burden_melt = burden_percent.melt(id_vars="cluster", 
                                   value_vars=burden_cols, 
                                   var_name="BurdenType", 
                                   value_name="Proportion")

# 排序 cluster 順序
burden_melt["cluster"] = burden_melt["cluster"].astype(str)

# 繪圖
plt.figure(figsize=(10, 6))
sns.barplot(
    data=burden_melt,
    x="cluster", y="Proportion", hue="BurdenType",
    palette="Set2"
)

plt.title("Housing Burden Composition by Cluster")
plt.ylabel("Proportion")
plt.xlabel("Cluster")
plt.legend(title="Burden Type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

import scipy.stats as stats
## copy data set to analysis 
fullDataCopy = fullDataset.copy()
fullDataCopy['log_eviction'] = np.log(fullDataCopy['filedEviction']+1)

median_anova = smf.mixedlm(formula='log_eviction ~ medianIncome+C(incomeLevel)', data=fullDataCopy, groups=fullDataCopy['cluster']).fit()
#anova_table = sm.stats.anova_lm(median_anova, typ=2)
#print(anova_table)
print(median_anova.summary())
# Out:
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                MixedLM     Dependent Variable:     log_eviction
# No. Observations:     1533        Method:                 REML
# No. Groups:           10          Scale:                  2.1640
# Min. group size:      26          Log-Likelihood:         -2789.8088
# Max. group size:      239         Converged:              Yes
# Mean group size:      153.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    3.226    0.276 11.706 0.000  2.686  3.766
# C(incomeLevel)[T.Moderate]   0.281    0.176  1.595 0.111 -0.064  0.627
# C(incomeLevel)[T.High]       0.348    0.243  1.434 0.152 -0.128  0.824
# C(incomeLevel)[T.Very High]  0.244    0.420  0.581 0.561 -0.579  1.066
# medianIncome                -0.000    0.000 -3.372 0.001 -0.000 -0.000
# Group Var                    0.100    0.042
# ======================================================================

# %%
eviction_anova = smf.mixedlm(formula='log_eviction ~ OwnerOccupied + RenterOccupied + C(LiveType)', data=fullDataCopy, groups=fullDataCopy['cluster']).fit()
#anova_table = sm.stats.anova_lm(eviction_anova, typ=2)
#print(anova_table)
print(eviction_anova.summary())
# Out:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                  MixedLM     Dependent Variable:     log_eviction
# No. Observations:       1533        Method:                 REML
# No. Groups:             10          Scale:                  2.0650
# Min. group size:        26          Log-Likelihood:         -2736.2376
# Max. group size:        239         Converged:              No
# Mean group size:        153.3
# ------------------------------------------------------------------------
#                               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                      2.582
# C(LiveType)[T.RenterOccupied] -0.319    0.157 -2.027 0.043 -0.627 -0.011
# OwnerOccupied                 -1.239
# RenterOccupied                 1.648
# Group Var                      2.065
# ========================================================================

# %%
burden_anova = smf.mixedlm(formula='log_eviction ~ lowBurdan + moderateBurdan + costBurdan + highBurdan+ C(burden)', data=fullDataCopy, groups=fullDataCopy['cluster']).fit()
print(burden_anova.summary())
# Out:
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                MixedLM     Dependent Variable:     log_eviction
# No. Observations:     1533        Method:                 REML
# No. Groups:           10          Scale:                  2.1113
# Min. group size:      26          Log-Likelihood:         -2766.4379
# Max. group size:      239         Converged:              No
# Mean group size:      153.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.230    0.454  0.507 0.612 -0.660  1.121
# C(burden)[T.highBurdan]     -0.213    0.146 -1.454 0.146 -0.500  0.074
# C(burden)[T.lowBurdan]      -0.426    0.264 -1.613 0.107 -0.944  0.092
# C(burden)[T.moderateBurdan] -0.249    0.142 -1.756 0.079 -0.526  0.029
# lowBurdan                    2.719    0.579  4.699 0.000  1.585  3.854
# moderateBurdan               2.415    0.478  5.047 0.000  1.477  3.352
# costBurdan                   1.856    0.457  4.058 0.000  0.959  2.752
# highBurdan                   2.512    0.524  4.797 0.000  1.486  3.539
# Group Var                    0.681    0.574
# ======================================================================

# %% [markdown]
# **Description:**The anova results showed that filed eviction cases are affected by compositions of rent burden with moderateBurden, costBurden and lowBurden.

# %%
ethical = fullDataCopy[[
    'cluster',
    'Majority',
    'filedEviction',
    'White Alone',
    'Black Alone',
    'Hispanic or Latino',
    'American Indian or Alaska Native Alone',
    'Asian Alone'
]].rename(columns={
    'cluster': 'cluster',
    'Majority': 'Majority',
    'White Alone': 'white',
    'Black Alone': 'black',
    'Hispanic or Latino': 'latino',
    'American Indian or Alaska Native Alone': 'native_american',
    'Asian Alone': 'asian'})

## rename data columns: 
fullDataCopy.rename(columns={
    'cluster': 'cluster',
    'Majority': 'Majority',
    'White Alone': 'white',
    'Black Alone': 'black',
    'Hispanic or Latino': 'latino',
    'American Indian or Alaska Native Alone': 'native_american',
    'Asian Alone': 'asian'}, inplace=True)

# Run ANOVA
Majority_anova = smf.mixedlm(
    formula='log_eviction ~white + black + latino + native_american + asian + C(Majority)',
    data=fullDataCopy,
    groups = fullDataCopy['cluster']
).fit()

print(Majority_anova.summary())
# Out:
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                  MixedLM       Dependent Variable:       log_eviction
# No. Observations:       1533          Method:                   REML
# No. Groups:             10            Scale:                    2.1208
# Min. group size:        26            Log-Likelihood:           -2759.2112
# Max. group size:        239           Converged:                Yes
# Mean group size:        153.3
# ----------------------------------------------------------------------------
#                                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------
# Intercept                          0.524    1.422  0.368 0.713 -2.264  3.311
# C(Majority)[T.Black Alone]         2.569    1.498  1.715 0.086 -0.366  5.505
# C(Majority)[T.Hispanic or Latino]  1.749    1.331  1.315 0.189 -0.859  4.357
# C(Majority)[T.White Alone]         2.061    1.322  1.560 0.119 -0.529  4.651
# white                             -1.045    0.700 -1.494 0.135 -2.416  0.326
# black                              1.840    1.053  1.747 0.081 -0.224  3.905
# latino                             0.681    0.543  1.254 0.210 -0.383  1.745
# native_american                    0.472    1.452  0.325 0.745 -2.374  3.318
# asian                              1.459    1.123  1.299 0.194 -0.742  3.660
# Group Var                          0.273    0.107
# ============================================================================

# %%
renamed_df = fullDataCopy.rename(columns={
    'Single-family homes': 'single_family',
    'Small multi-unit buildings (2-4 units)': 'small_multi',
    'Larger apartment complexes (5+ units)': 'large_apartment',
    'Mobile homes, boats, RVs, etc.': 'mobile_other'
})

## rename data columns: 
fullDataCopy.rename(columns={
    'Single-family homes': 'single_family',
    'Small multi-unit buildings (2-4 units)': 'small_multi',
    'Larger apartment complexes (5+ units)': 'large_apartment',
    'Mobile homes, boats, RVs, etc.': 'mobile_other'
}, inplace=True)

majorHouseType_anova = smf.mixedlm(
    formula='log_eviction ~ single_family + small_multi + large_apartment + mobile_other + C(majorHouseType)',
    data=renamed_df, 
    groups=renamed_df['cluster']
).fit()

print(majorHouseType_anova.summary())
# Out:
#                                  Mixed Linear Model Regression Results
# =======================================================================================================
# Model:                           MixedLM                Dependent Variable:                log_eviction
# No. Observations:                1533                   Method:                            REML
# No. Groups:                      10                     Scale:                             2.0577
# Min. group size:                 26                     Log-Likelihood:                    -2733.0611
# Max. group size:                 239                    Converged:                         Yes
# Mean group size:                 153.3
# -------------------------------------------------------------------------------------------------------
#                                                             Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                                                    3.970    0.338  11.755 0.000  3.308  4.632
# C(majorHouseType)[T.Single-family homes]                     0.172    0.299   0.578 0.563 -0.413  0.758
# C(majorHouseType)[T.Small multi-unit buildings (2-4 units)] -0.627    0.611  -1.027 0.305 -1.823  0.570
# single_family                                               -2.847    0.268 -10.626 0.000 -3.373 -2.322
# small_multi                                                 -3.162    2.705  -1.169 0.242 -8.464  2.140
# large_apartment                                             -4.253    1.256  -3.387 0.001 -6.714 -1.792
# mobile_other                                                -2.110    0.471  -4.479 0.000 -3.033 -1.186
# Group Var                                                    0.079    0.036
# =======================================================================================================

# %%
final_lme = smf.mixedlm(formula = 'log_eviction ~ lowBurdan + moderateBurdan + costBurdan + highBurdan + medianIncome+white+latino+C(cluster)', data=fullDataCopy, groups=fullDataCopy['cluster']).fit()

print(final_lme.summary())

print(final_lme)
# Out:
#            Mixed Linear Model Regression Results
# ===========================================================
# Model:             MixedLM Dependent Variable: log_eviction
# No. Observations:  1533    Method:             REML
# No. Groups:        10      Scale:              2.0973
# Min. group size:   26      Log-Likelihood:     -2758.2810
# Max. group size:   239     Converged:          Yes
# Mean group size:   153.3
# -----------------------------------------------------------
#                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------
# Intercept         1.434    1.567  0.915 0.360 -1.637  4.506
# C(cluster)[T.2]  -0.435    2.110 -0.206 0.837 -4.570  3.700
# C(cluster)[T.3]   0.547    2.058  0.266 0.790 -3.487  4.581
# C(cluster)[T.4]   0.220    2.061  0.107 0.915 -3.819  4.259
# C(cluster)[T.5]   0.600    2.059  0.291 0.771 -3.436  4.636
# C(cluster)[T.6]  -0.018    2.081 -0.009 0.993 -4.097  4.061
# C(cluster)[T.7]  -0.870    2.192 -0.397 0.691 -5.165  3.425
# C(cluster)[T.8]   0.018    2.062  0.009 0.993 -4.023  4.060
# C(cluster)[T.9]   0.402    2.067  0.195 0.846 -3.649  4.454
# C(cluster)[T.10]  0.121    2.067  0.058 0.953 -3.931  4.172
# lowBurdan         2.351    0.537  4.375 0.000  1.298  3.404
# moderateBurdan    1.981    0.439  4.512 0.000  1.121  2.842
# costBurdan        2.080    0.420  4.947 0.000  1.256  2.904
# highBurdan        2.195    0.459  4.780 0.000  1.295  3.096
# medianIncome     -0.000    0.000 -0.675 0.500 -0.000  0.000
# white            -1.395    0.390 -3.574 0.000 -2.161 -0.630
# latino           -0.174    0.359 -0.485 0.628 -0.878  0.530
# Group Var         2.097
# ===========================================================
#
# <statsmodels.regression.mixed_linear_model.MixedLMResultsWrapper object at 0x7f3426e010>
